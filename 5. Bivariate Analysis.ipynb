# %% [markdown]
# ![title](Innomatics-Research-Labs.png)

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
#  -     Bivariate analysis can help determine to what extent it becomes easier to know and predict a value for one variable (possibly a dependent variable) if we know the value of the other variable (possibly the independent variable)

# %%
#Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Reading the excel file which is obtained from data cleaning 

df=pd.read_excel('1.3 current.xlsx')
df.head()
# Out:
#               title     location  price(L)  rate_persqft  area_insqft  \
# 0  Residential Plot  Maheshwaram     45.00          1111         4050
# 1  Residential Plot     Kondakal     34.00          2361         1440
# 2  Residential Plot    Bibinagar     14.19           944         1503
# 3  Residential Plot   Gachibowli    330.00          3333         9900
# 4  Residential Plot    Shadnagar      6.72           466         1440
#
#   building_status  agent_rating
# 0             New           4.6
# 1             New           3.7
# 2             New           4.9
# 3             New           0.0
# 4             New           4.7

# %%
print('Min price:',df['price(L)'].min(),'\nMax price:',df['price(L)'].max())
# Out:
# Min price: 0.16
# Max price: 7000.0

# %% [markdown]
# # Interval(0.16-10L)

# %% [markdown]
# #### Based on price we have sorted the data frame
# - Plotted the graph between two variables.
# - All these operations are comprised in a function for better use.
# - Through this we can plot between any variables.

# %%
def bivarant_swarm(col1,col2,x,y):
    c=df[(df['price(L)']>=x)&(df['price(L)']<=y)]
    c=c.sort_values(by='price(L)',ascending=False)
    k=c[col1].head(30)
    l=c[col2].head(30)
    fig,ax=plt.subplots(figsize=(10,5))
    fig.suptitle(' Swarmplot between two varibles')
    sns.swarmplot(x=k,y=l,data=c,ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=50,ha='right')
    ax.set_yscale('linear')
    plt.show()
     ######High then low########
    c=c.sort_values(by='price(L)',ascending=True)
    k=c[col1].head(30)
    l=c[col2].head(30)
    fig,ax1=plt.subplots(figsize=(10,5))
    sns.swarmplot(x=k,y=l,data=c,ax=ax1)
    ax1.set_xticklabels(ax1.get_xticklabels(),rotation=50,ha='right')
    ax1.set_yscale('log')
    plt.show()

# %% [markdown]
# ### title Vs price(L)

# %%
bivarant_swarm('title','price(L)',0.16,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly, highest price is for Residential Plots and lowest for 1 BHK Apartment and 2 BHK Apartment
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly, lowest price is for 3 BHK Apartment

# %%
def bivarant_box(col1,col2,x,y):
    c=df[(df['price(L)']>=x)&(df['price(L)']<=y)]
    c=c.sort_values(by='price(L)',ascending=False)
    k=c[col1].head(20)
    l=c[col2].head(20)
    fig,ax=plt.subplots(figsize=(10,5))
    fig.suptitle("Box plot between 2 variables")
    sns.boxplot(x=k,y=l,data=c,ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=50,ha='right')
    ######## High then Low####
    c=c.sort_values(by='price(L)',ascending=True)
    k=c[col1].head(20)
    l=c[col2].head(20)
    fig,ax1=plt.subplots(figsize=(10,5))
    sns.boxplot(x=k,y=l,data=c,ax=ax1)
    ax1.set_xticklabels(ax1.get_xticklabels(),rotation=50,ha='right')
    plt.show()

# %% [markdown]
# ### Area_insqft Vs price(L)

# %%
bivarant_box('area_insqft','price(L)',0.6,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly,same price for each kind of area per sqft
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly,lowest price is for 400 and 460 sqfts

# %%
def bivarant_violin(col1,col2,x,y):
    c=df[(df['price(L)']>=x)&(df['price(L)']<=y)]
    c=c.sort_values(by='price(L)',ascending=False)
    k=c[col1].head(20)
    l=c[col2].head(20)
    fig,ax=plt.subplots(figsize=(10,5))
    fig.suptitle(" Violin plot between 2 variables")
    sns.violinplot(x=k,y=l,data=c,ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=50,ha='right')
    ######## High then Low####
    c=c.sort_values(by='price(L)',ascending=True)
    k=c[col1].head(20)
    l=c[col2].head(20)
    fig,ax1=plt.subplots(figsize=(10,5))
    sns.violinplot(x=k,y=l,data=c,ax=ax1)
    ax1.set_xticklabels(ax1.get_xticklabels(),rotation=50,ha='right')
    plt.show()

# %% [markdown]
# ### area_insqft Vs rate_persqft

# %%
bivarant_violin('area_insqft','rate_persqft',0.6,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly,maximum area in sqft is for rate in range of 0 to 1000 per sqft
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly,minimum area in sqft is  for 275 rate per sqft

# %% [markdown]
# ### location Vs price(L)

# %%
bivarant_box('location','price(L)',0.6,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly,same price for each kind of location
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly,lowest price 1.1L is for 400 and 460 sqfts

# %% [markdown]
# ### agent_rating Vs price(L)

# %%
bivarant_violin('agent_rating','price(L)',0.6,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly,maximum price is same for all agent ratings
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly,minimum price of 1.8L is for the agent with rating 4.8
#    - Rating of 5 with maximum price 1.9L is considered,if needed.

# %%
bivarant_swarm('location','price(L)',0.6,10)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 16K to 10L from high to low price for **top 30**
#    - Mostly,maximum price is same for each location
# ###### Graph 2:
#    - For the price range of 16K to 10L from low to high price for **bottom 30**
#    - Mostly,minimum price is there for Chikkadapally,Kadthal,Kothur,Ramoji Film city

# %% [markdown]
# # Interval (30-40L)

# %% [markdown]
# ### title Vs price(L)

# %%
bivarant_swarm('title','price(L)',30,40)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 30L to 40L from high to low price for **top 30**
#    - Mostly, highest price  of 40L is there for 2 BHK Apartment,1 BHK Apartment and Residential plot
#    - In this, Residential plots are more in number for the maximum price approximately.
# ###### Graph 2:
#    - For the price range of 100L to 700L from low to high price for **bottom 30**
#    - Mostly, lowest price of 30L is there for all kinds of properties.
#    - In this,Residential plots are more in number for the minimum price approximately.

# %% [markdown]
# ### area_insqft Vs price(L)

# %%
bivarant_box('area_insqft','price(L)',30,40)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 30L to 40L from high to low price for **top 30**
#    - Mostly, highest price  of 40L is there for all areas in sqft in this plot
# ###### Graph 2:
#    - For the price range of 30L to 40L from low to high price for **bottom 30**
#    - Mostly, lowest price of 30L is there for all areas in sqft in this plot

# %% [markdown]
# ### location Vs price(L)

# %%
bivarant_violin('location','price(L)',30,40)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 30L to 40L from high to low price for **top 30**
#    - Mostly, highest price  of 40L is there for 2 BHK Apartment,1 BHK Apartment and Residential plot
#    - In this, Residential plots are more in number for the maximum price approximately.
# ###### Graph 2:
#    - For the price range of 100L to 700L from low to high price for **bottom 30**
#    - Mostly, lowest price of 30L is there for all kinds of properties.
#    - In this,Residential plots are more in number for the minimum price approximately.

# %% [markdown]
# # Interval (60-70L)

# %%
bivarant_swarm('title','price(L)',60,70)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 60L to 70L from high to low price for **top 30**
#    - Mostly, highest price is for all kinds of properties
#    - In this, 3 BHK Apartments are more in number for the maximum price approximately.
# ###### Graph 2:
#    - For the price range of 60L to 70L from low to high price for **bottom 30**
#    - Mostly, lowest price is for all kinds of properties
#    - In this,3 BHK Apartments are more in number for the minimum price approximately.

# %%
bivarant_swarm('area_insqft','price(L)',60,70)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 60L to 70L from high to low price for **top 30**
#    - Mostly, highest price of 70L is there for all areas in sqft
#    - In this,1254 and 1450 are the areas in sqft are having maximum price approximately.
# ###### Graph 2:
#    - For the price range of 60L to 70L from low to high price for **bottom 30**
#    - Mostly, lowest price of 60 L is for all kinds of areas in sqft
#    - In this,1450 and 2439 are the areas in sqft having minimum price approximately.

# %%
bivarant_swarm('location','price(L)',60,70)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 60L to 70L from high to low price for **top 30**
#    - Mostly, highest price of 70L is there for all locations
#    - In this,Tellapur is having more number of maximum prices approximately.
# ###### Graph 2:
#    - For the price range of 60L to 70L from low to high price for **bottom 30**
#    - Mostly, lowest price of 60 L is there for all locations
#    - In this,ECIL Main Road is having more number ofa minimum price approximately.

# %% [markdown]
# # Interval (100-700L)

# %%
bivarant_swarm('title','price(L)',100,7000)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 100L to 700L from high to low price for **top 30**
#    - Mostly, highest price  of 70 Cr is for 4 BHK Independent House.
#    - In this, Residential plots are more in number for the maximum price approximately.
# ###### Graph 2:
#    - For the price range of 100L to 700L from low to high price for **bottom 30**
#    - Mostly, lowest price of 1 Cr is there for all kinds of properties
#    - In this,3 BHK Apartments are more in number for the minimum price approximately.

# %%
bivarant_swarm('area_insqft','price(L)',100,7000)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 100L to 700L from high to low price for **top 30**
#    - Mostly, highest price  of 70 Cr is there for area 4058 in sqft.
# ###### Graph 2:
#    - For the price range of 100L to 700L from low to high price for **bottom 30**
#    - Mostly, lowest price of 1 Cr is there for all areas in sqft under this range.
#    - In this,areas with value of 1800 in sqft are more in number for the minimum price approximately.

# %%
bivarant_swarm('location','price(L)',100,7000)

# %% [markdown]
# #### Observation:
# ###### Graph 1 :
#    - For the price range of 100L to 700L from high to low price for **top 30**
#    - Mostly, highest price  of 70 Cr is there for Banjara Hills.
#    - In this, Jubliee Hills is having more number of properties for the maximum price approximately.
# ###### Graph 2:
#    - For the price range of 100L to 700L from low to high price for **bottom 30**
#    - Mostly, lowest price of 1 Cr is there for all locations in this range.
#    - In this,Kondapur is more in number for the minimum price approximately.
